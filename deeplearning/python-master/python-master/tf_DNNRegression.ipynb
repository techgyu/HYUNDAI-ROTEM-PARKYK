# %%
import pandas as pd
import tensorflow as tf

# %%
tf.logging.set_verbosity(tf.logging.INFO)

COLUMNS = ["crim", "zn", "indus", "nox", "rm", "age", "dis", "tax", "ptratio", "medv"]
FEATURES = ["crim", "zn", "indus", "nox", "rm", "age", "dis", "tax", "ptratio"]
LABEL = "medv"

training_set = pd.read_csv("boston_train.csv", skipinitialspace=True,
                           skiprows=1, names=COLUMNS)
test_set = pd.read_csv("boston_test.csv", skipinitialspace=True,
                           skiprows=1, names=COLUMNS)
prediction_set = pd.read_csv("boston_predict.csv", skipinitialspace=True,
                            skiprows=1, names=COLUMNS)
feature_cols = [tf.feature_column.numeric_column(k) for k in FEATURES]

regressor = tf.estimator.DNNRegressor(feature_columns=feature_cols,
                                      hidden_units=[10, 10],
                                      model_dir="./tmp/boston_model")

def get_input_fn(data_set, num_epochs=None, shuffle=True):
  return tf.estimator.inputs.pandas_input_fn(
      x=pd.DataFrame({k: data_set[k].values for k in FEATURES}),
      y = pd.Series(data_set[LABEL].values),
      num_epochs=num_epochs,
      shuffle=shuffle)

regressor.train(input_fn=get_input_fn(training_set), steps=5000)

ev = regressor.evaluate(input_fn=get_input_fn(test_set, num_epochs=1, shuffle=False))
loss_score = ev["loss"]
print("Loss: {0:f}".format(loss_score))

# 예측하기
import itertools
y = regressor.predict(input_fn=get_input_fn(prediction_set, num_epochs=1, shuffle=False))
# .predict() returns an iterator of dicts; convert to a list and print predictions

predictions = list(p["predictions"] for p in itertools.islice(y, 6))
print("Predictions: {}".format(str(predictions)))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './tmp/boston_model', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x00000235B6496F60>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./tmp/boston_model\model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 20000 into ./tmp/boston_model\model.ckpt.
# INFO:tensorflow:loss = 3985.5205, step = 20001
# INFO:tensorflow:global_step/sec: 266.82
# INFO:tensorflow:loss = 2447.091, step = 20101 (0.378 sec)
# INFO:tensorflow:global_step/sec: 346.22
# INFO:tensorflow:loss = 3644.6194, step = 20201 (0.287 sec)
# INFO:tensorflow:global_step/sec: 343.84
# INFO:tensorflow:loss = 4782.093, step = 20301 (0.292 sec)
# INFO:tensorflow:global_step/sec: 341.493
# INFO:tensorflow:loss = 3024.169, step = 20401 (0.294 sec)
# INFO:tensorflow:global_step/sec: 345.026
# INFO:tensorflow:loss = 4012.5215, step = 20501 (0.290 sec)
# INFO:tensorflow:global_step/sec: 330.224
# INFO:tensorflow:loss = 4676.2886, step = 20601 (0.304 sec)
# INFO:tensorflow:global_step/sec: 340.332
# INFO:tensorflow:loss = 4172.913, step = 20701 (0.293 sec)
# INFO:tensorflow:global_step/sec: 345.024
# INFO:tensorflow:loss = 2954.4368, step = 20801 (0.290 sec)
# INFO:tensorflow:global_step/sec: 341.494
# INFO:tensorflow:loss = 3056.955, step = 23201 (0.288 sec)
# INFO:tensorflow:global_step/sec: 335.763
# INFO:tensorflow:loss = 2081.1482, step = 23301 (0.298 sec)
# INFO:tensorflow:global_step/sec: 343.841
# INFO:tensorflow:loss = 6626.4062, step = 23401 (0.291 sec)
# INFO:tensorflow:global_step/sec: 339.178
# INFO:tensorflow:loss = 2681.9521, step = 23501 (0.295 sec)
# INFO:tensorflow:global_step/sec: 235.15
# INFO:tensorflow:loss = 2137.566, step = 23601 (0.425 sec)
# INFO:tensorflow:global_step/sec: 230.547
# INFO:tensorflow:loss = 2919.3564, step = 23701 (0.441 sec)
# INFO:tensorflow:global_step/sec: 110.928
# INFO:tensorflow:loss = 2179.691, step = 23801 (0.898 sec)
# INFO:tensorflow:global_step/sec: 275.052
# INFO:tensorflow:loss = 2909.5444, step = 23901 (0.361 sec)
# INFO:tensorflow:global_step/sec: 300.551
# INFO:tensorflow:loss = 2908.0698, step = 24001 (0.331 sec)
# INFO:tensorflow:global_step/sec: 274.868
# INFO:tensorflow:loss = 5037.366, step = 24101 (0.366 sec)
# INFO:tensorflow:global_step/sec: 277.937
# INFO:tensorflow:loss = 4487.741, step = 24201 (0.360 sec)
# INFO:tensorflow:global_step/sec: 264.004
# INFO:tensorflow:loss = 4097.691, step = 24301 (0.378 sec)
# INFO:tensorflow:global_step/sec: 283.449
# INFO:tensorflow:loss = 2469.83, step = 24401 (0.354 sec)
# INFO:tensorflow:global_step/sec: 274.883
# INFO:tensorflow:loss = 3507.4985, step = 24501 (0.364 sec)
# INFO:tensorflow:global_step/sec: 265.404
# INFO:tensorflow:loss = 3870.0378, step = 24601 (0.376 sec)
# INFO:tensorflow:global_step/sec: 290.021
# INFO:tensorflow:loss = 1785.8896, step = 24701 (0.345 sec)
# INFO:tensorflow:global_step/sec: 266.111
# INFO:tensorflow:loss = 2817.2888, step = 24801 (0.377 sec)
# INFO:tensorflow:global_step/sec: 271.158
# INFO:tensorflow:loss = 2028.467, step = 24901 (0.369 sec)
# INFO:tensorflow:Saving checkpoints for 25000 into ./tmp/boston_model\model.ckpt.
# WARNING:tensorflow:From C:\python\Anaconda3\envs\test\lib\site-packages\tensorflow\python\training\saver.py:966: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Loss for final step: 3242.8557.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-03T02:35:21Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./tmp/boston_model\model.ckpt-25000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-04-03-02:35:21
# INFO:tensorflow:Saving dict for global step 25000: average_loss = 13.165715, global_step = 25000, label/mean = 22.08, loss = 1316.5715, prediction/mean = 23.518736
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 25000: ./tmp/boston_model\model.ckpt-25000
# Loss: 1316.571533
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./tmp/boston_model\model.ckpt-25000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Predictions: [array([34.23842], dtype=float32), array([17.681452], dtype=float32), array([24.39741], dtype=float32), array([35.54891], dtype=float32), array([15.705995], dtype=float32), array([19.329256], dtype=float32)]
